# %% [markdown]
# # Recommender Model

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('Datasets/recipes_food_com.csv')
df.head()
# Out:
#        ID                                               Name  \
# 0   71247                            Cherry Streusel Cobbler
# 1   76133                    Reuben and Swiss Casserole Bake
# 2  503816                                   Yam-Pecan Recipe
# 3  418749                         Tropical Orange Layer Cake
# 4  392934  Safe to Eat Raw Chocolate Chip Oreo Cookie "do...
#
#                                          Description  \
# 0  I haven't made this in years, so I'm just gues...
# 1  I think this is even better than a reuben sand...
# 2  A lady I work with heard me taking about ZWT a...
# 3  An easy and delicious cake.  Great for a  summ...
# 4  I was searching the web for something like thi...
#
#                                 IngredientsExtracted  \
# 0  cherry pie filling condensed milk melted marga...
# 1  corned beef chopped sauerkraut cold water swis...
# 2  unsalted butter vegetable oil all  purpose flo...
# 3  orange cake mix instant vanilla pudding orange...
# ...

# %%
vec = TfidfVectorizer()

vecs = vec.fit_transform(df['IngredientsExtracted'].apply(lambda x: np.str_(x)))

# %%
vecs.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 vecs.shape()
#
# TypeError: 'tuple' object is not callable
