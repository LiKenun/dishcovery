# %% [markdown]
# # Exploratory Data Analysis (EDA) and Extract Transform Load (ETL)

# %%
import html

from ast import literal_eval
from constants import Paths
from dataclasses import dataclass
from functools import partial
from IPython.display import display, display_html, display_markdown
from pandas import DataFrame, read_csv
from pathlib import Path
from pprint import pformat

display_html = partial(display_html, raw = True)

display_markdown = partial(display_markdown, raw = True)

def display_python_structure(value) -> None:
    print(pformat(value, 4))

def display_top_rows(df: DataFrame) -> None:
    display_markdown('#### Top Rows')
    display(df.head(10))
    display_markdown('**Dataframe shape:** {:,} rows × {:,} columns'.format(*df.shape))

def ensure_parent_exists(path: str) -> None:
    Path(path).parent.mkdir(parents = True, exist_ok = True)

# %% [markdown]
# ## USDA FoodData Central Dataset

# %%
@dataclass(frozen = True, slots = True)
class NutrientInfo:
    name: str
    dv_factor: float

def read_nutrient_data():
    return read_csv(Paths.NUTRIENT_DATASET, index_col = 'id')

def read_food_data():
    return read_csv(Paths.FOOD_DATASET, index_col = 'fdc_id')

def read_food_nutrient_data():
    return read_csv(Paths.FOOD_NUTRIENT_DATASET, index_col = 'id')

# %% [markdown]
# ### Nutrients

# %%
nutrient_df: DataFrame = read_nutrient_data()

display_top_rows(nutrient_df)
# Out:
# #### Top Rows
#                                       name unit_name  nutrient_nbr      rank
# id
# 2047      Energy (Atwater General Factors)      KCAL         957.0     280.0
# 2048     Energy (Atwater Specific Factors)      KCAL         958.0     290.0
# 1001                                Solids         G         201.0     200.0
# 1002                              Nitrogen         G         202.0     500.0
# 1003                               Protein         G         203.0     600.0
# 1004                     Total lipid (fat)         G         204.0     800.0
# 1005           Carbohydrate, by difference         G         205.0    1110.0
# 1006  Fiber, crude (DO NOT USE - Archived)         G         206.0  999999.0
# 1007                                   Ash         G         207.0    1000.0
# 1008                                Energy      KCAL         208.0     300.0
# **Dataframe shape:** 477 rows × 4 columns

# %% [markdown]
# Hmm… it’s got a lot of extra data we do not need. We need to be selective.

# %% [markdown]
# ### Foods

# %%
food_df: DataFrame = read_food_data()

display_top_rows(food_df)
# Out:
# #### Top Rows
#                  data_type                                        description  \
# fdc_id
# 1105904       branded_food                         WESSON Vegetable Oil 1 GAL
# 1105905       branded_food                                 SWANSON BROTH BEEF
# 1105906       branded_food           CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 1105907       branded_food        CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 1105898  experimental_food  Discrepancy between the Atwater factor predict...
# 1105899  experimental_food  Food processing and structure impact the metab...
# 1105900  experimental_food  Metabolizable Energy from Cashew Nuts is Less ...
# 1105901  experimental_food  Measured energy value of pistachios in the hum...
# 1105902  experimental_food  Walnuts Consumed by Healthy Adults Provide Les...
# 1105908       branded_food                              SWANSON BROTH CHICKEN
#
#               food_category_id publication_date
# fdc_id
# 1105904            Oils Edible       2020-11-13
# 1105905  Herbs/Spices/Extracts       2020-11-13
# 1105906         Prepared Soups       2020-11-13
# 1105907         Prepared Soups       2020-11-13
# 1105898                    NaN       2020-10-30
# 1105899                    NaN       2020-10-30
# 1105900                    NaN       2020-10-30
# 1105901                    NaN       2020-10-30
# 1105902                    NaN       2020-10-30
# 1105908  Herbs/Spices/Extracts       2020-11-13
# **Dataframe shape:** 2,059,641 rows × 4 columns

# %% [markdown]
# OK. We got our foods. Now… what foods have what?

# %% [markdown]
# ### Foods × Nutrients

# %%
food_nutrient_df: DataFrame = read_food_nutrient_data()

display_top_rows(food_nutrient_df)
# Out:
# C:\Users\Kevin Li\AppData\Local\Temp\ipykernel_5220\1771124419.py:13: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(Paths.FOOD_NUTRIENT_DATASET, index_col = 'id')
# #### Top Rows
#            fdc_id  nutrient_id  amount  data_points  derivation_id  min  max  \
# id
# 13706927  1105904         1257    0.00          NaN           71.0  NaN  NaN
# 13706930  1105904         1293   53.33          NaN           71.0  NaN  NaN
# 13706926  1105904         1253    0.00          NaN           75.0  NaN  NaN
# 13706921  1105904         1092    0.00          NaN           75.0  NaN  NaN
# 13706916  1105904         1008  867.00          NaN           71.0  NaN  NaN
# 13706920  1105904         1089    0.00          NaN           75.0  NaN  NaN
# 13706925  1105904         1162    0.00          NaN           75.0  NaN  NaN
# 13706928  1105904         1258   13.33          NaN           71.0  NaN  NaN
# 13706919  1105904         1087    0.00          NaN           75.0  NaN  NaN
# 13706929  1105904         1292   20.00          NaN           71.0  NaN  NaN
#
#           median  loq footnote  min_year_acquired  percent_daily_value
# id
# 13706927     NaN  NaN      NaN                NaN                  NaN
# 13706930     NaN  NaN      NaN                NaN                  0.0
# 13706926     NaN  NaN      NaN                NaN                  0.0
# 13706921     NaN  NaN      NaN                NaN                  0.0
# 13706916     NaN  NaN      NaN                NaN                  NaN
# 13706920     NaN  NaN      NaN                NaN                  0.0
# 13706925     NaN  NaN      NaN                NaN                  0.0
# 13706928     NaN  NaN      NaN                NaN                 10.0
# 13706919     NaN  NaN      NaN                NaN                  0.0
# 13706929     NaN  NaN      NaN                NaN                  0.0
# **Dataframe shape:** 26,770,242 rows × 12 columns

# %% [markdown]
# Let’s join them and see if we can spot any patterns in the resulting data.

# %%
nutrition_fact_df: DataFrame = food_nutrient_df[['fdc_id', 'nutrient_id', 'amount']] \
                              .join(food_df[['description']], 'fdc_id', 'inner') \
                              .join(nutrient_df[['name', 'unit_name']], 'nutrient_id', 'inner') \
                              .pipe(lambda df: df.drop_duplicates(['fdc_id', 'nutrient_id'])) \
                              .pipe(lambda df: df.assign(nutrient_value = df.apply(lambda row: f'{row.amount:,} {row.unit_name.lower()}', axis = 1))) \
                              .pivot(index = ['fdc_id', 'description'], columns = ['nutrient_id', 'name'], values = 'nutrient_value') \
                              .dropna(how = 'all')

display_top_rows(nutrition_fact_df)
# Out:
# #### Top Rows
# nutrient_id                                                                   1257  \
# name                                                      Fatty acids, total trans
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...                  4.412 g
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                   4.29 g
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...                      NaN
# 167515 George Weston Bakeries, Thomas English Muffins                      0.082 g
# 167516 Waffles, buttermilk, frozen, ready-to-heat                              NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted                      NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...                      NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave                         NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...                      NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                        0.0 g
#
# nutrient_id                                                                             1293  \
# name                                                      Fatty acids, total polyunsaturated
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...                                NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...                                NaN
# 167515 George Weston Bakeries, Thomas English Muffins                                 0.92 g
# 167516 Waffles, buttermilk, frozen, ready-to-heat                                    1.445 g
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted                            1.502 g
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...                            1.615 g
# 167519 Waffle, plain, frozen, ready-to-heat, microwave                                2.24 g
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...                            1.671 g
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                                2.035 g
#
# nutrient_id                                                      1253  \
# name                                                      Cholesterol
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...      0.0 mg
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...      0.0 mg
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...         NaN
# 167515 George Weston Bakeries, Thomas English Muffins             NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat             15.0 mg
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted     13.0 mg
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...     16.0 mg
# 167519 Waffle, plain, frozen, ready-to-heat, microwave        16.0 mg
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...      0.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust          0.0 mg
#
# nutrient_id                                                       1092  \
# name                                                      Potassium, K
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...          NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...          NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...          NaN
# 167515 George Weston Bakeries, Thomas English Muffins              NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat             126.0 mg
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted     138.0 mg
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...     110.0 mg
# 167519 Waffle, plain, frozen, ready-to-heat, microwave        148.0 mg
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...     113.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust         187.0 mg
#
# nutrient_id                                                      1008  \
# name                                                           Energy
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...  307.0 kcal
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  330.0 kcal
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...  377.0 kcal
# 167515 George Weston Bakeries, Thomas English Muffins      232.0 kcal
# 167516 Waffles, buttermilk, frozen, ready-to-heat          273.0 kcal
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted  309.0 kcal
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...  289.0 kcal
# 167519 Waffle, plain, frozen, ready-to-heat, microwave     298.0 kcal
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...  501.0 kcal
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust      484.0 kcal
#
# nutrient_id                                                   1089  \
# name                                                      Iron, Fe
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...  2.12 mg
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  1.93 mg
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...      NaN
# 167515 George Weston Bakeries, Thomas English Muffins       1.4 mg
# 167516 Waffles, buttermilk, frozen, ready-to-heat          6.04 mg
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted  6.59 mg
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...  6.53 mg
# 167519 Waffle, plain, frozen, ready-to-heat, microwave     5.81 mg
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...   2.6 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust       4.3 mg
#
# nutrient_id                                                                         1162  \
# name                                                      Vitamin C, total ascorbic acid
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...                            NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                         0.1 mg
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...                            NaN
# 167515 George Weston Bakeries, Thomas English Muffins                                NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                                 0.0 mg
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted                         0.0 mg
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...                         0.0 mg
# 167519 Waffle, plain, frozen, ready-to-heat, microwave                               NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...                         0.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                             0.0 mg
#
# nutrient_id                                                                       1258  \
# name                                                      Fatty acids, total saturated
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...                      2.941 g
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                       3.25 g
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...                          NaN
# 167515 George Weston Bakeries, Thomas English Muffins                          0.308 g
# 167516 Waffles, buttermilk, frozen, ready-to-heat                              1.898 g
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted                      2.275 g
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...                      2.057 g
# 167519 Waffle, plain, frozen, ready-to-heat, microwave                          1.58 g
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...                      4.999 g
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                          4.725 g
#
# nutrient_id                                                      1087  \
# name                                                      Calcium, Ca
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...         NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...     28.0 mg
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...         NaN
# 167515 George Weston Bakeries, Thomas English Muffins        180.0 mg
# 167516 Waffles, buttermilk, frozen, ready-to-heat            279.0 mg
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted    299.0 mg
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...    125.0 mg
# 167519 Waffle, plain, frozen, ready-to-heat, microwave       197.0 mg
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...     29.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust         32.0 mg
#
# nutrient_id                                                                             1292  \
# name                                                      Fatty acids, total monounsaturated
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...                                NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...                                NaN
# 167515 George Weston Bakeries, Thomas English Muffins                                0.303 g
# 167516 Waffles, buttermilk, frozen, ready-to-heat                                     4.53 g
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted                            5.292 g
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...                            4.864 g
# 167519 Waffle, plain, frozen, ready-to-heat, microwave                               5.195 g
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...                           16.928 g
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                               14.482 g
#
# nutrient_id                                                ...       2063  \
# name                                                       ... Verbascose
# fdc_id description                                         ...
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...  ...        NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  ...        NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...  ...        NaN
# 167515 George Weston Bakeries, Thomas English Muffins      ...        NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat          ...        NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted  ...        NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...  ...        NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave     ...        NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...  ...        NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust      ...        NaN
#
# nutrient_id                                                      1041  \
# name                                                      Oxalic acid
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...         NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...         NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...         NaN
# 167515 George Weston Bakeries, Thomas English Muffins             NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                 NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted         NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...         NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave            NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...         NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust             NaN
#
# nutrient_id                                                      1044  \
# name                                                      Quinic acid
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...         NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...         NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...         NaN
# 167515 George Weston Bakeries, Thomas English Muffins             NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                 NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted         NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...         NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave            NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...         NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust             NaN
#
# nutrient_id                                                                                      2038  \
# name                                                      High Molecular Weight Dietary Fiber (HMWDF)
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...                                         NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                         NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...                                         NaN
# 167515 George Weston Bakeries, Thomas English Muffins                                             NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                                                 NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted                                         NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...                                         NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave                                            NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...                                         NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                                             NaN
#
# nutrient_id                                                                                     2065  \
# name                                                      Low Molecular Weight Dietary Fiber (LMWDF)
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...                                        NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                        NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...                                        NaN
# 167515 George Weston Bakeries, Thomas English Muffins                                            NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                                                NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted                                        NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...                                        NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave                                           NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...                                        NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                                            NaN
#
# nutrient_id                                                       1043  \
# name                                                      Pyruvic acid
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...          NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...          NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...          NaN
# 167515 George Weston Bakeries, Thomas English Muffins              NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                  NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted          NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...          NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave             NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...          NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust              NaN
#
# nutrient_id                                                       1068  \
# name                                                      Beta-glucans
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...          NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...          NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...          NaN
# 167515 George Weston Bakeries, Thomas English Muffins              NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                  NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted          NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...          NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave             NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...          NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust              NaN
#
# nutrient_id                                                    2067      2068  \
# name                                                      Vitamin A Vitamin E
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...       NaN       NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...       NaN       NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...       NaN       NaN
# 167515 George Weston Bakeries, Thomas English Muffins           NaN       NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat               NaN       NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted       NaN       NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...       NaN       NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave          NaN       NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...       NaN       NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust           NaN       NaN
#
# nutrient_id                                                     1149
# name                                                      Salt, NaCl
# fdc_id description
# 167512 Pillsbury Golden Layer Buttermilk Biscuits, Art...        NaN
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...        NaN
# 167514 Kraft Foods, Shake N Bake Original Recipe, Coat...        NaN
# 167515 George Weston Bakeries, Thomas English Muffins            NaN
# 167516 Waffles, buttermilk, frozen, ready-to-heat                NaN
# 167517 Waffle, buttermilk, frozen, ready-to-heat, toasted        NaN
# 167518 Waffle, buttermilk, frozen, ready-to-heat, micr...        NaN
# 167519 Waffle, plain, frozen, ready-to-heat, microwave           NaN
# 167520 Pie Crust, Cookie-type, Graham Cracker, Ready C...        NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust            NaN
#
# [10 rows x 268 columns]
# **Dataframe shape:** 1,944,807 rows × 268 columns

# %% [markdown]
# Whoah! That’s a lot of missing values. Can we just drop the foods for which we have very little nutrition data on? Let’s make the criteria be “missing a few key nutrition facts.”

# %%
key_nutrients: list[str] = nutrition_fact_df.describe() \
                                            .transpose() \
                                            .sort_values('count', ascending = False) \
                                            .head(12) \
                                            .index \
                                            .to_list()

display_markdown('**Important Values**')
display_python_structure(key_nutrients)
# Out:
# **Important Values**
# [   (1003, 'Protein'),
#     (1005, 'Carbohydrate, by difference'),
#     (1093, 'Sodium, Na'),
#     (1008, 'Energy'),
#     (1004, 'Total lipid (fat)'),
#     (2000, 'Total Sugars'),
#     (1258, 'Fatty acids, total saturated'),
#     (1253, 'Cholesterol'),
#     (1079, 'Fiber, total dietary'),
#     (1257, 'Fatty acids, total trans'),
#     (1087, 'Calcium, Ca'),
#     (1089, 'Iron, Fe')]

# %%
nutrition_fact_df: DataFrame = nutrition_fact_df.dropna(subset = key_nutrients)

display_top_rows(nutrition_fact_df)
# Out:
# #### Top Rows
# nutrient_id                                                                   1257  \
# name                                                      Fatty acids, total trans
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                   4.29 g
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                        0.0 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                        0.2 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                  2.027 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                        2.853 g
# 167532 Bread, white wheat                                                  0.031 g
# 167533 Bagels, wheat                                                         0.0 g
# 167534 Cream puff, eclair, custard or cream filled, iced                     0.0 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                  0.014 g
# 167537 Snacks, corn-based, extruded, chips, plain                          0.088 g
#
# nutrient_id                                                                             1293  \
# name                                                      Fatty acids, total polyunsaturated
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                                2.035 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                                3.272 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                            4.428 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                  2.835 g
# 167532 Bread, white wheat                                                            0.973 g
# 167533 Bagels, wheat                                                                 0.936 g
# 167534 Cream puff, eclair, custard or cream filled, iced                             4.173 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                            2.152 g
# 167537 Snacks, corn-based, extruded, chips, plain                                   16.438 g
#
# nutrient_id                                                      1253  \
# name                                                      Cholesterol
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...      0.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust          0.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat         21.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...     59.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)           10.0 mg
# 167532 Bread, white wheat                                      0.0 mg
# 167533 Bagels, wheat                                           0.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced      66.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...      0.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain              0.0 mg
#
# nutrient_id                                                       1092  \
# name                                                      Potassium, K
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...          NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust         187.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat          74.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...     350.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)           103.0 mg
# 167532 Bread, white wheat                                     127.0 mg
# 167533 Bagels, wheat                                          165.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced       68.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...     133.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain             144.0 mg
#
# nutrient_id                                                      1008  \
# name                                                           Energy
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  330.0 kcal
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust      484.0 kcal
# 167524 Waffles, chocolate chip, frozen, ready-to-heat      297.0 kcal
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...  374.0 kcal
# 167528 Pastry, Pastelitos de Guava (guava pastries)        379.0 kcal
# 167532 Bread, white wheat                                  238.0 kcal
# 167533 Bagels, wheat                                       250.0 kcal
# 167534 Cream puff, eclair, custard or cream filled, iced   334.0 kcal
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...  297.0 kcal
# 167537 Snacks, corn-based, extruded, chips, plain          539.0 kcal
#
# nutrient_id                                                   1089  \
# name                                                      Iron, Fe
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  1.93 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust       4.3 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat       6.4 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...  0.98 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)        2.12 mg
# 167532 Bread, white wheat                                  4.89 mg
# 167533 Bagels, wheat                                       2.76 mg
# 167534 Cream puff, eclair, custard or cream filled, iced   0.95 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...  3.32 mg
# 167537 Snacks, corn-based, extruded, chips, plain           1.2 mg
#
# nutrient_id                                                                         1162  \
# name                                                      Vitamin C, total ascorbic acid
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                         0.1 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                             0.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                             0.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                         0.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                  NaN
# 167532 Bread, white wheat                                                         0.0 mg
# 167533 Bagels, wheat                                                              0.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced                          0.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                         0.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain                                 0.0 mg
#
# nutrient_id                                                                       1258  \
# name                                                      Fatty acids, total saturated
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                       3.25 g
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                          4.725 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                          3.567 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                      4.612 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                            5.535 g
# 167532 Bread, white wheat                                                       0.63 g
# 167533 Bagels, wheat                                                             0.0 g
# 167534 Cream puff, eclair, custard or cream filled, iced                       7.055 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                      1.225 g
# 167537 Snacks, corn-based, extruded, chips, plain                              4.331 g
#
# nutrient_id                                                      1087  \
# name                                                      Calcium, Ca
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...     28.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust         32.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat        357.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...     73.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)           14.0 mg
# 167532 Bread, white wheat                                    684.0 mg
# 167533 Bagels, wheat                                          20.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced      35.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...    163.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain            138.0 mg
#
# nutrient_id                                                                             1292  \
# name                                                      Fatty acids, total monounsaturated
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                               14.482 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                                2.564 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                            6.794 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                  8.543 g
# 167532 Bread, white wheat                                                            0.393 g
# 167533 Bagels, wheat                                                                  0.29 g
# 167534 Cream puff, eclair, custard or cream filled, iced                              6.07 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                            3.801 g
# 167537 Snacks, corn-based, extruded, chips, plain                                    9.134 g
#
# nutrient_id                                                ...       2063  \
# name                                                       ... Verbascose
# fdc_id description                                         ...
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  ...        NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust      ...        NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat      ...        NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...  ...        NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)        ...        NaN
# 167532 Bread, white wheat                                  ...        NaN
# 167533 Bagels, wheat                                       ...        NaN
# 167534 Cream puff, eclair, custard or cream filled, iced   ...        NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...  ...        NaN
# 167537 Snacks, corn-based, extruded, chips, plain          ...        NaN
#
# nutrient_id                                                      1041  \
# name                                                      Oxalic acid
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...         NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust             NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat             NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...         NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)               NaN
# 167532 Bread, white wheat                                         NaN
# 167533 Bagels, wheat                                              NaN
# 167534 Cream puff, eclair, custard or cream filled, iced          NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...         NaN
# 167537 Snacks, corn-based, extruded, chips, plain                 NaN
#
# nutrient_id                                                      1044  \
# name                                                      Quinic acid
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...         NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust             NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat             NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...         NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)               NaN
# 167532 Bread, white wheat                                         NaN
# 167533 Bagels, wheat                                              NaN
# 167534 Cream puff, eclair, custard or cream filled, iced          NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...         NaN
# 167537 Snacks, corn-based, extruded, chips, plain                 NaN
#
# nutrient_id                                                                                      2038  \
# name                                                      High Molecular Weight Dietary Fiber (HMWDF)
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                         NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                                             NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                                             NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                                         NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                               NaN
# 167532 Bread, white wheat                                                                         NaN
# 167533 Bagels, wheat                                                                              NaN
# 167534 Cream puff, eclair, custard or cream filled, iced                                          NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                                         NaN
# 167537 Snacks, corn-based, extruded, chips, plain                                                 NaN
#
# nutrient_id                                                                                     2065  \
# name                                                      Low Molecular Weight Dietary Fiber (LMWDF)
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                        NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                                            NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                                            NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                                        NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                              NaN
# 167532 Bread, white wheat                                                                        NaN
# 167533 Bagels, wheat                                                                             NaN
# 167534 Cream puff, eclair, custard or cream filled, iced                                         NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                                        NaN
# 167537 Snacks, corn-based, extruded, chips, plain                                                NaN
#
# nutrient_id                                                       1043  \
# name                                                      Pyruvic acid
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...          NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust              NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat              NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...          NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)                NaN
# 167532 Bread, white wheat                                          NaN
# 167533 Bagels, wheat                                               NaN
# 167534 Cream puff, eclair, custard or cream filled, iced           NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...          NaN
# 167537 Snacks, corn-based, extruded, chips, plain                  NaN
#
# nutrient_id                                                       1068  \
# name                                                      Beta-glucans
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...          NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust              NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat              NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...          NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)                NaN
# 167532 Bread, white wheat                                          NaN
# 167533 Bagels, wheat                                               NaN
# 167534 Cream puff, eclair, custard or cream filled, iced           NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...          NaN
# 167537 Snacks, corn-based, extruded, chips, plain                  NaN
#
# nutrient_id                                                    2067      2068  \
# name                                                      Vitamin A Vitamin E
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...       NaN       NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust           NaN       NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat           NaN       NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...       NaN       NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)             NaN       NaN
# 167532 Bread, white wheat                                       NaN       NaN
# 167533 Bagels, wheat                                            NaN       NaN
# 167534 Cream puff, eclair, custard or cream filled, iced        NaN       NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...       NaN       NaN
# 167537 Snacks, corn-based, extruded, chips, plain               NaN       NaN
#
# nutrient_id                                                     1149
# name                                                      Salt, NaCl
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...        NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust            NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat            NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...        NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)              NaN
# 167532 Bread, white wheat                                        NaN
# 167533 Bagels, wheat                                             NaN
# 167534 Cream puff, eclair, custard or cream filled, iced         NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...        NaN
# 167537 Snacks, corn-based, extruded, chips, plain                NaN
#
# [10 rows x 268 columns]
# **Dataframe shape:** 1,374,521 rows × 268 columns

# %% [markdown]
# Let’s do the same to columns which are mostly empty.

# %%
spotty_nutrients: list[str] = nutrition_fact_df.describe() \
                                               .transpose() \
                                               .sort_values('count') \
                                               .pipe(lambda df: df[df['count'] < df['count'].quantile(0.85)]) \
                                               .index \
                                               .to_list()

display_markdown('**Unimportant Values**')
display_python_structure(spotty_nutrients)
# Out:
# **Unimportant Values**
# [   (1149, 'Salt, NaCl'),
#     (1121, 'Lutein'),
#     (1159, 'cis-beta-Carotene'),
#     (1160, 'cis-Lycopene'),
#     (2032, 'Cryptoxanthin, alpha'),
#     (1161, 'cis-Lutein/Zeaxanthin'),
#     (1330, 'Fatty acids, total trans-dienoic'),
#     (1050, 'Carbohydrate, by summation'),
#     (2026, 'PUFA 20:2 c'),
#     (1063, 'Sugars, Total'),
#     (2020, 'PUFA 20:3 c'),
#     (2024, 'PUFA 22:5 c'),
#     (2010, 'MUFA 17:1 c'),
#     (2016, 'PUFA 18:2 c'),
#     (2018, 'PUFA 18:3 c'),
#     (2023, 'PUFA 20:5c'),
#     (2025, 'PUFA 22:6 c'),
#     (2022, 'PUFA 20:4c'),
#     (2047, 'Energy (Atwater General Factors)'),
#     (2048, 'Energy (Atwater Specific Factors)'),
#     (1117, 'Phytofluene'),
#     (1116, 'Phytoene'),
#     (2029, 'trans-Lycopene'),
#     (2028, 'trans-beta-Carotene'),
#     (1119, 'Zeaxanthin'),
#     (2003, 'SFA 5:0'),
#     (1335, 'SFA 11:0'),
#     (1414, 'PUFA 20:3 n-9'),
#     (2012, 'MUFA 20:1 c'),
#     (1334, 'PUFA 22:2'),
#     (2014, 'MUFA 22:1 n-9'),
#     (2019, 'TFA 18:3 t'),
#     (2009, 'MUFA 14:1 c'),
#     (1197, 'Choline, from glycerophosphocholine'),
#     (1195, 'Choline, from phosphocholine'),
#     (1196, 'Choline, from phosphotidyl choline'),
#     (1024, 'Specific Gravity'),
#     (1194, 'Choline, free'),
#     (1113, '25-hydroxycholecalciferol'),
#     (2006, 'SFA 21:0'),
#     (2005, 'SFA 9:0'),
#     (2004, 'SFA 7:0'),
#     (2015, 'MUFA 22:1 n-11'),
#     (2021, 'PUFA 22:3'),
#     (2007, 'SFA 23:0'),
#     (1281, 'TFA 14:1 t'),
#     (2013, 'TFA 20:1 t'),
#     (2008, 'MUFA 12:1'),
#     (1199, 'Choline, from sphingomyelin'),
#     (1002, 'Nitrogen'),
#     (1192, '5-Formyltetrahydrofolic acid (5-HCOH4'),
#     (1188, '5-methyl tetrahydrofolate (5-MTHF)'),
#     (2049, 'Daidzin'),
#     (1118, 'Carotene, gamma'),
#     (2053, 'Stigmastadiene'),
#     (2052, 'Delta-7-Stigmastenol'),
#     (2069, 'Glutathione'),
#     (2058, 'Beta-glucan'),
#     (2061, 'Ergosta-7,22-dienol'),
#     (1284, 'Ergosterol'),
#     (2059, 'Vitamin D4'),
#     (2060, 'Ergosta-7-enol'),
#     (2062, 'Ergosta-5,7-dienol'),
#     (2057, 'Ergothioneine'),
#     (1076, 'Raffinose'),
#     (1077, 'Stachyose'),
#     (2063, 'Verbascose'),
#     (1041, 'Oxalic acid'),
#     (1044, 'Quinic acid'),
#     (2038, 'High Molecular Weight Dietary Fiber (HMWDF)'),
#     (2065, 'Low Molecular Weight Dietary Fiber (LMWDF)'),
#     (1043, 'Pyruvic acid'),
#     (1068, 'Beta-glucans'),
#     (2051, 'Glycitin'),
#     (1191, '10-Formyl folic acid (10HCOFA)'),
#     (1341, 'Genistein'),
#     (2050, 'Genistin'),
#     (1097, 'Cobalt, Co'),
#     (1094, 'Sulfur, S'),
#     (1081, 'Ribose'),
#     (1026, 'Acetic acid'),
#     (1038, 'Lactic acid'),
#     (1340, 'Daidzein'),
#     (1294, 'Beta-sitostanol'),
#     (1146, 'Nickel, Ni'),
#     (1289, 'Campestanol'),
#     (1287, 'Brassicasterol'),
#     (1296, 'Delta-5-avenasterol'),
#     (2033, 'Total dietary fiber (AOAC 2011.25)'),
#     (1039, 'Malic acid'),
#     (1032, 'Citric acid'),
#     (1236, 'Sugars, intrinsic'),
#     (2017, 'TFA 18:2 t'),
#     (1298, 'Phytosterols, other'),
#     (1137, 'Boron, B'),
#     (1368, 'Epigallocatechin-3-gallate'),
#     (1080, 'Lignin'),
#     (1233, 'Glutamine'),
#     (1181, 'Inositol'),
#     (1234, 'Taurine'),
#     (1307, 'PUFA 18:2 i'),
#     (1410, 'PUFA 21:5'),
#     (1286, 'Campesterol'),
#     (1285, 'Stigmasterol'),
#     (1288, 'Beta-sitosterol'),
#     (1111, 'Vitamin D2 (ergocalciferol)'),
#     (1232, 'Cysteine'),
#     (1403, 'Inulin'),
#     (1056, 'Sorbitol'),
#     (1408, 'PUFA 20:4 n-6'),
#     (1332, 'SFA 13:0'),
#     (1078, 'Xylitol'),
#     (1412, 'MUFA 18:1-11 t (18:1t n-7)'),
#     (1283, 'Phytosterols'),
#     (1085, 'Total fat (NLEA)'),
#     (1099, 'Fluoride, F'),
#     (1310, 'TFA 18:2 t,t'),
#     (1183, 'Vitamin K (Menaquinone-4)'),
#     (1409, 'PUFA 18:3i'),
#     (1009, 'Starch'),
#     (1305, 'TFA 22:1 t'),
#     (1411, 'PUFA 22:4'),
#     (1184, 'Vitamin K (Dihydrophylloquinone)'),
#     (1405, 'PUFA 20:3 n-3'),
#     (1317, 'MUFA 22:1 c'),
#     (1130, 'Tocotrienol, gamma'),
#     (1228, 'Hydroxyproline'),
#     (1131, 'Tocotrienol, delta'),
#     (1128, 'Tocotrienol, alpha'),
#     (1129, 'Tocotrienol, beta'),
#     (1306, 'TFA 18:2 t not further defined'),
#     (1075, 'Galactose'),
#     (1303, 'TFA 16:1 t'),
#     (1406, 'PUFA 20:3 n-6'),
#     (1312, 'MUFA 24:1 c'),
#     (1014, 'Maltose'),
#     (1010, 'Sucrose'),
#     (1011, 'Glucose'),
#     (1012, 'Fructose'),
#     (1127, 'Tocopherol, delta'),
#     (1126, 'Tocopherol, gamma'),
#     (1125, 'Tocopherol, beta'),
#     (1314, 'MUFA 16:1 c'),
#     (1112, 'Vitamin D3 (cholecalciferol)'),
#     (1311, 'PUFA 18:2 CLAs'),
#     (1321, 'PUFA 18:3 n-6 c,c,c'),
#     (1198, 'Betaine'),
#     (1331, 'Fatty acids, total trans-polyenoic'),
#     (1333, 'MUFA 15:1'),
#     (1316, 'PUFA 18:2 n-6 c,c'),
#     (1315, 'MUFA 18:1 c'),
#     (1273, 'SFA 22:0'),
#     (1404, 'PUFA 18:3 n-3 c,c,c (ALA)'),
#     (1329, 'Fatty acids, total trans-monoenoic'),
#     (1304, 'TFA 18:1 t'),
#     (1299, 'SFA 15:0'),
#     (1301, 'SFA 24:0'),
#     (1325, 'PUFA 20:3'),
#     (1088, 'Chlorine, Cl'),
#     (2068, 'Vitamin E'),
#     (1323, 'MUFA 17:1'),
#     (1313, 'PUFA 20:2 n-6 c,c'),
#     (1274, 'MUFA 14:1'),
#     (1300, 'SFA 17:0'),
#     (1267, 'SFA 20:0'),
#     (1216, 'Cystine'),
#     (1223, 'Aspartic acid'),
#     (1013, 'Lactose'),
#     (1224, 'Glutamic acid'),
#     (1225, 'Glycine'),
#     (1227, 'Serine'),
#     (1226, 'Proline'),
#     (1218, 'Tyrosine'),
#     (1222, 'Alanine'),
#     (1210, 'Tryptophan'),
#     (1211, 'Threonine'),
#     (1213, 'Leucine'),
#     (1212, 'Isoleucine'),
#     (1221, 'Histidine'),
#     (1217, 'Phenylalanine'),
#     (1220, 'Arginine'),
#     (1219, 'Valine'),
#     (1215, 'Methionine'),
#     (1214, 'Lysine'),
#     (1242, 'Vitamin E, added'),
#     (1246, 'Vitamin B-12, added'),
#     (1018, 'Alcohol, ethyl'),
#     (1058, 'Theobromine'),
#     (1096, 'Chromium, Cr'),
#     (1272, 'PUFA 22:6 n-3 (DHA)'),
#     (1187, 'Folate, food'),
#     (1279, 'MUFA 22:1'),
#     (1280, 'PUFA 22:5 n-3 (DPA)'),
#     (1278, 'PUFA 20:5 n-3 (EPA)'),
#     (1276, 'PUFA 18:4'),
#     (1260, 'SFA 6:0'),
#     (1259, 'SFA 4:0'),
#     (1271, 'PUFA 20:4'),
#     (1122, 'Lycopene'),
#     (1277, 'MUFA 20:1'),
#     (1261, 'SFA 8:0'),
#     (1120, 'Cryptoxanthin, beta'),
#     (1108, 'Carotene, alpha'),
#     (1262, 'SFA 10:0'),
#     (1123, 'Lutein + zeaxanthin'),
#     (1263, 'SFA 12:0'),
#     (1275, 'MUFA 16:1'),
#     (1264, 'SFA 14:0'),
#     (1107, 'Carotene, beta'),
#     (1270, 'PUFA 18:3'),
#     (1266, 'SFA 18:0'),
#     (1105, 'Retinol'),
#     (1265, 'SFA 16:0'),
#     (1269, 'PUFA 18:2'),
#     (1268, 'MUFA 18:1'),
#     (1102, 'Molybdenum, Mo'),
#     (1062, 'Energy'),
#     (1180, 'Choline, total'),
#     (1057, 'Caffeine'),
#     (1176, 'Biotin'),
#     (1072, 'Carbohydrate, other'),
#     (1109, 'Vitamin E (alpha-tocopherol)'),
#     (1106, 'Vitamin A, RAE'),
#     (1190, 'Folate, DFE'),
#     (1051, 'Water'),
#     (1124, 'Vitamin E (label entry primarily)'),
#     (1007, 'Ash')]

# %%
nutrition_fact_df: DataFrame = nutrition_fact_df.drop(columns = spotty_nutrients)

display_top_rows(nutrition_fact_df)
# Out:
# #### Top Rows
# nutrient_id                                                                   1257  \
# name                                                      Fatty acids, total trans
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                   4.29 g
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                        0.0 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                        0.2 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                  2.027 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                        2.853 g
# 167532 Bread, white wheat                                                  0.031 g
# 167533 Bagels, wheat                                                         0.0 g
# 167534 Cream puff, eclair, custard or cream filled, iced                     0.0 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                  0.014 g
# 167537 Snacks, corn-based, extruded, chips, plain                          0.088 g
#
# nutrient_id                                                                             1293  \
# name                                                      Fatty acids, total polyunsaturated
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                                2.035 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                                3.272 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                            4.428 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                  2.835 g
# 167532 Bread, white wheat                                                            0.973 g
# 167533 Bagels, wheat                                                                 0.936 g
# 167534 Cream puff, eclair, custard or cream filled, iced                             4.173 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                            2.152 g
# 167537 Snacks, corn-based, extruded, chips, plain                                   16.438 g
#
# nutrient_id                                                      1253  \
# name                                                      Cholesterol
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...      0.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust          0.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat         21.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...     59.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)           10.0 mg
# 167532 Bread, white wheat                                      0.0 mg
# 167533 Bagels, wheat                                           0.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced      66.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...      0.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain              0.0 mg
#
# nutrient_id                                                       1092  \
# name                                                      Potassium, K
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...          NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust         187.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat          74.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...     350.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)           103.0 mg
# 167532 Bread, white wheat                                     127.0 mg
# 167533 Bagels, wheat                                          165.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced       68.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...     133.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain             144.0 mg
#
# nutrient_id                                                      1008  \
# name                                                           Energy
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  330.0 kcal
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust      484.0 kcal
# 167524 Waffles, chocolate chip, frozen, ready-to-heat      297.0 kcal
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...  374.0 kcal
# 167528 Pastry, Pastelitos de Guava (guava pastries)        379.0 kcal
# 167532 Bread, white wheat                                  238.0 kcal
# 167533 Bagels, wheat                                       250.0 kcal
# 167534 Cream puff, eclair, custard or cream filled, iced   334.0 kcal
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...  297.0 kcal
# 167537 Snacks, corn-based, extruded, chips, plain          539.0 kcal
#
# nutrient_id                                                   1089  \
# name                                                      Iron, Fe
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  1.93 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust       4.3 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat       6.4 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...  0.98 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)        2.12 mg
# 167532 Bread, white wheat                                  4.89 mg
# 167533 Bagels, wheat                                       2.76 mg
# 167534 Cream puff, eclair, custard or cream filled, iced   0.95 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...  3.32 mg
# 167537 Snacks, corn-based, extruded, chips, plain           1.2 mg
#
# nutrient_id                                                                         1162  \
# name                                                      Vitamin C, total ascorbic acid
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                         0.1 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                             0.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                             0.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                         0.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                  NaN
# 167532 Bread, white wheat                                                         0.0 mg
# 167533 Bagels, wheat                                                              0.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced                          0.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                         0.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain                                 0.0 mg
#
# nutrient_id                                                                       1258  \
# name                                                      Fatty acids, total saturated
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                       3.25 g
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                          4.725 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                          3.567 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                      4.612 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                            5.535 g
# 167532 Bread, white wheat                                                       0.63 g
# 167533 Bagels, wheat                                                             0.0 g
# 167534 Cream puff, eclair, custard or cream filled, iced                       7.055 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                      1.225 g
# 167537 Snacks, corn-based, extruded, chips, plain                              4.331 g
#
# nutrient_id                                                      1087  \
# name                                                      Calcium, Ca
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...     28.0 mg
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust         32.0 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat        357.0 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...     73.0 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)           14.0 mg
# 167532 Bread, white wheat                                    684.0 mg
# 167533 Bagels, wheat                                          20.0 mg
# 167534 Cream puff, eclair, custard or cream filled, iced      35.0 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...    163.0 mg
# 167537 Snacks, corn-based, extruded, chips, plain            138.0 mg
#
# nutrient_id                                                                             1292  \
# name                                                      Fatty acids, total monounsaturated
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                                NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                               14.482 g
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                                2.564 g
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                            6.794 g
# 167528 Pastry, Pastelitos de Guava (guava pastries)                                  8.543 g
# 167532 Bread, white wheat                                                            0.393 g
# 167533 Bagels, wheat                                                                  0.29 g
# 167534 Cream puff, eclair, custard or cream filled, iced                              6.07 g
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                            3.801 g
# 167537 Snacks, corn-based, extruded, chips, plain                                    9.134 g
#
# nutrient_id                                                ...      1100  \
# name                                                       ... Iodine, I
# fdc_id description                                         ...
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...  ...       NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust      ...       NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat      ...       NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...  ...       NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)        ...       NaN
# 167532 Bread, white wheat                                  ...       NaN
# 167533 Bagels, wheat                                       ...       NaN
# 167534 Cream puff, eclair, custard or cream filled, iced   ...       NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...  ...       NaN
# 167537 Snacks, corn-based, extruded, chips, plain          ...       NaN
#
# nutrient_id                                                   1095      1158  \
# name                                                      Zinc, Zn Vitamin E
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...      NaN       NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust       2.1 mg       NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat       0.4 mg       NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...   0.8 mg       NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)        0.42 mg       NaN
# 167532 Bread, white wheat                                  0.95 mg       NaN
# 167533 Bagels, wheat                                        1.1 mg       NaN
# 167534 Cream puff, eclair, custard or cream filled, iced   0.45 mg       NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...  0.57 mg       NaN
# 167537 Snacks, corn-based, extruded, chips, plain          1.29 mg       NaN
#
# nutrient_id                                                         1082  \
# name                                                      Fiber, soluble
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...            NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...            NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)                  NaN
# 167532 Bread, white wheat                                            NaN
# 167533 Bagels, wheat                                                 NaN
# 167534 Cream puff, eclair, custard or cream filled, iced             NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...            NaN
# 167537 Snacks, corn-based, extruded, chips, plain                    NaN
#
# nutrient_id                                                           1084  \
# name                                                      Fiber, insoluble
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...              NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                  NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                  NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...              NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)                    NaN
# 167532 Bread, white wheat                                              NaN
# 167533 Bagels, wheat                                                   NaN
# 167534 Cream puff, eclair, custard or cream filled, iced               NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...              NaN
# 167537 Snacks, corn-based, extruded, chips, plain                      NaN
#
# nutrient_id                                                               1086  \
# name                                                      Total sugar alcohols
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                  NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                      NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                      NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                  NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)                        NaN
# 167532 Bread, white wheat                                                  NaN
# 167533 Bagels, wheat                                                       NaN
# 167534 Cream puff, eclair, custard or cream filled, iced                   NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                  NaN
# 167537 Snacks, corn-based, extruded, chips, plain                          NaN
#
# nutrient_id                                                                    1185  \
# name                                                      Vitamin K (phylloquinone)
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                       NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                       18.2 ug
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                        9.3 ug
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...                   11.2 ug
# 167528 Pastry, Pastelitos de Guava (guava pastries)                         12.5 ug
# 167532 Bread, white wheat                                                    7.7 ug
# 167533 Bagels, wheat                                                         1.5 ug
# 167534 Cream puff, eclair, custard or cream filled, iced                     6.7 ug
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...                    4.2 ug
# 167537 Snacks, corn-based, extruded, chips, plain                            6.3 ug
#
# nutrient_id                                                     1098  \
# name                                                      Copper, Cu
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...        NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust        0.77 mg
# 167524 Waffles, chocolate chip, frozen, ready-to-heat       0.221 mg
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...    0.03 mg
# 167528 Pastry, Pastelitos de Guava (guava pastries)         0.079 mg
# 167532 Bread, white wheat                                   0.149 mg
# 167533 Bagels, wheat                                        0.175 mg
# 167534 Cream puff, eclair, custard or cream filled, iced     0.06 mg
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...   0.115 mg
# 167537 Snacks, corn-based, extruded, chips, plain           0.101 mg
#
# nutrient_id                                                              1114  \
# name                                                      Vitamin D (D2 + D3)
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...                 NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust                  0.0 ug
# 167524 Waffles, chocolate chip, frozen, ready-to-heat                  0.1 ug
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...              0.3 ug
# 167528 Pastry, Pastelitos de Guava (guava pastries)                       NaN
# 167532 Bread, white wheat                                              0.0 ug
# 167533 Bagels, wheat                                                   0.0 ug
# 167534 Cream puff, eclair, custard or cream filled, iced               0.3 ug
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...              0.0 ug
# 167537 Snacks, corn-based, extruded, chips, plain                      0.0 ug
#
# nutrient_id                                                    2067
# name                                                      Vitamin A
# fdc_id description
# 167513 Pillsbury, Cinnamon Rolls with Icing, refrigera...       NaN
# 167521 Pie Crust, Cookie-type, Chocolate, Ready Crust           NaN
# 167524 Waffles, chocolate chip, frozen, ready-to-heat           NaN
# 167526 Bread, salvadoran sweet cheese (quesadilla salv...       NaN
# 167528 Pastry, Pastelitos de Guava (guava pastries)             NaN
# 167532 Bread, white wheat                                       NaN
# 167533 Bagels, wheat                                            NaN
# 167534 Cream puff, eclair, custard or cream filled, iced        NaN
# 167535 Tortillas, ready-to-bake or -fry, flour, shelf ...       NaN
# 167537 Snacks, corn-based, extruded, chips, plain               NaN
#
# [10 rows x 41 columns]
# **Dataframe shape:** 1,374,521 rows × 41 columns

# %% [markdown]
# What’s left after the fray?

# %%
nutrition_fact_df.columns \
                 .to_frame(index = False) \
                 .set_index('nutrient_id') \
                 .join(nutrient_df.unit_name) \
                 .sort_values('name') \
                 .pipe(display)
# Out:
#                                                  name unit_name
# nutrient_id
# 1087                                      Calcium, Ca        MG
# 1005                      Carbohydrate, by difference         G
# 1253                                      Cholesterol        MG
# 1098                                       Copper, Cu        MG
# 1008                                           Energy      KCAL
# 1292               Fatty acids, total monounsaturated         G
# 1293               Fatty acids, total polyunsaturated         G
# 1258                     Fatty acids, total saturated         G
# 1257                         Fatty acids, total trans         G
# 1084                                 Fiber, insoluble         G
# 1082                                   Fiber, soluble         G
# 1079                             Fiber, total dietary         G
# 1177                                    Folate, total        UG
# 1186                                       Folic acid        UG
# 1100                                        Iodine, I        UG
# 1089                                         Iron, Fe        MG
# 1090                                    Magnesium, Mg        MG
# 1101                                    Manganese, Mn        MG
# 1167                                           Niacin        MG
# 1170                                 Pantothenic acid        MG
# 1091                                    Phosphorus, P        MG
# 1092                                     Potassium, K        MG
# 1003                                          Protein         G
# 1166                                       Riboflavin        MG
# 1103                                     Selenium, Se        UG
# 1093                                       Sodium, Na        MG
# 1235                                    Sugars, added         G
# 1165                                          Thiamin        MG
# 2000                                     Total Sugars         G
# 1004                                Total lipid (fat)         G
# 1086                             Total sugar alcohols         G
# 2067                                        Vitamin A        UG
# 1104                                    Vitamin A, IU        IU
# 1178                                     Vitamin B-12        UG
# 1175                                      Vitamin B-6        MG
# 1162                   Vitamin C, total ascorbic acid        MG
# 1114                              Vitamin D (D2 + D3)        UG
# 1110         Vitamin D (D2 + D3), International Units        IU
# 1158                                        Vitamin E    MG_ATE
# 1185                        Vitamin K (phylloquinone)        UG
# 1095                                         Zinc, Zn        MG

# %% [markdown]
# With the analysis above informing us, let’s be very selective about what to keep.

# %% [markdown]
# ### Extract, Transform, and Load

# %% [markdown]
# #### Nutrient Selection
#
# This part requires a bit of additional legwork and manual fine-tuning. Use the findings above as a clue, and research the info you need to fill in.

# %%
select_nutrients: dict[int, NutrientInfo] = {  # Nutrient identifier mapped to column name and DV factor
    1004: NutrientInfo('total_fat',       78), # g  of total fat
    1253: NutrientInfo('cholesterol',    300), # mg of cholesterol
    1005: NutrientInfo('carbohydrate',   300), # g  of carbohydrate
    1079: NutrientInfo('dietary_fiber',   28), # g  of dietary fiber
    1003: NutrientInfo('protein',         50), # g  of protein
    1104: NutrientInfo('vitamin_a',     3000), # UI of vitamin A
    1167: NutrientInfo('niacin',          16), # mg of niacin
    1166: NutrientInfo('riboflavin',     1.3), # mg of riboflavin
    1165: NutrientInfo('thiamin',        1.2), # mg of thiamin
    1170: NutrientInfo('pantothenic_acid', 5), # mg of pantothenic acid
    1175: NutrientInfo('vitamin_b6',     1.7), # mg of vitamin B₆
    1177: NutrientInfo('folate',         400), # µg of folate
    1178: NutrientInfo('vitamin_b12',    2.4), # µg of vitamin B₁₂
    1162: NutrientInfo('vitamin_c',       90), # mg of vitamin C
    1110: NutrientInfo('vitamin_d',      800), # IU of vitamin D
    1158: NutrientInfo('vitamin_e',       15), # mg of vitamin E
    1185: NutrientInfo('vitamin_c',      120), # µg of vitamin K
    1087: NutrientInfo('calcium',       1000), # mg of calcium
    1098: NutrientInfo('copper',         900), # µg of copper
    1100: NutrientInfo('iodine',         150), # µg of iodine
    1089: NutrientInfo('iron',            18), # mg of iron
    1090: NutrientInfo('magnesium',      420), # mg of magnesium
    1101: NutrientInfo('manganese',      2.3), # mg of manganese
    1091: NutrientInfo('phosphorus',    1250), # mg of phosphorus
    1092: NutrientInfo('potassium',     3400), # mg of potassium
    1103: NutrientInfo('selenium',        55), # µg of selenium
    1093: NutrientInfo('sodium',        2300), # mg of sodium
    1095: NutrientInfo('zinc',            11)  # mg of zinc
}

# %% [markdown]
# #### Save the Table as a Resource for Further Use
#
# Assuming you’ve defined `select_nutrients: dict[int, NutrientInfo]` above, the following extracts, transforms, and saves the nutrition data in one step.

# %%
ensure_parent_exists(Paths.NUTRITION_DATA_RESOURCE)
read_food_nutrient_data().drop_duplicates(['fdc_id', 'nutrient_id']) \
                         .pipe(lambda df: df[df.nutrient_id.isin(select_nutrients)]) \
                         .pipe(lambda df: df.assign(dv            = df.apply(lambda row: row.amount / select_nutrients[row.nutrient_id].dv_factor, axis = 1),
                                                    nutrient_name = df.apply(lambda row: select_nutrients[row.nutrient_id].name, axis = 1))) \
                         .get(['fdc_id', 'nutrient_name', 'dv']) \
                         .join(read_food_data().get(['description']), 'fdc_id', 'inner') \
                         .drop_duplicates(['fdc_id', 'description']) \
                         .pivot(index = ['fdc_id', 'description'], columns = 'nutrient_name', values = 'dv') \
                         .to_csv(Paths.NUTRITION_DATA_RESOURCE)
display_html(f'Saved nutrition data to <em>{html.escape(Paths.NUTRITION_DATA_RESOURCE)}</em>.')
# Out:
# C:\Users\Kevin Li\AppData\Local\Temp\ipykernel_5220\1771124419.py:13: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(Paths.FOOD_NUTRIENT_DATASET, index_col = 'id')
# Saved nutrition data to <em>resources/nutrition.csv</em>.

# %% [markdown]
# ## Food.com Recipes with Ingredients and Tags Dataset

# %%
def read_recipe_term_tag_data():
    return read_csv(Paths.RECIPE_TERM_TAG_DATASET,
                    index_col = 'id',
                    converters = {
                        column: html.unescape # Converts HTML escape sequences back to human-readable characters
                        for column in ('name', 'description')
                    } | {
                        column: lambda value: tuple(map(html.unescape, literal_eval(value)))
                        for column in ('ingredients', 'ingredients_raw_str', 'search_terms', 'steps')
                    } | {
                        'tags': lambda value: frozenset(map(html.unescape, literal_eval(value)))
                    })

# %%
recipe_term_tag_df: DataFrame = read_recipe_term_tag_data()

display_top_rows(recipe_term_tag_df)
display_markdown('---')
display_markdown('#### Top Row\n\nLook at this *structured* data. 🙂')
display_python_structure(recipe_term_tag_df.iloc[0].to_dict())
# Out:
# #### Top Rows
#                                          name  \
# id
# 96313             Grilled Garlic Cheese Grits
# 232037  Simple Shrimp and Andouille Jambalaya
# 41090              black-and-white bean salad
# 60656              Crock Pot Italian Zucchini
# 232047          Beef Stew With Dried Cherries
# 232050               Hot Sweet Almond Brittle
# 232076        Retro Chicken & Chips Casserole
# 232083              Asparagus  Omelette Wraps
# 79222                     Potato-Crab Chowder
# 393638           Sweet and Simple Sloppy Joes
#
#                                               description  \
# id
# 96313   We love grits, this is another good way to ser...
# 232037  Simple, easy and very tasty for when you are i...
# 41090
# 60656   This is a good recipe for weight watchers. It ...
# 232047  This is a fabulous stew that came from one of ...
# 232050  This is one of our standard holiday gift recip...
# 232076  From Cooking Light Magazine, 11/05. This is co...
# 232083  These wraps make a lovely breakfast, light lun...
# 79222                                  Soup for the soul!
# 393638  Easy and kid-friendly recipe that I always hav...
#
#                                               ingredients  \
# id
# 96313   (water, grits, salt, cheddar cheese, garlic, o...
# 232037  (onion, red bell pepper, garlic cloves, large ...
# 41090   (white beans, canned black beans, tomatoes, on...
# 60656   (zucchini, yellow squash, diced tomatoes, onio...
# 232047  (beef stew meat, flour, salt, allspice, cinnam...
# 232050  (slivered almonds, cider vinegar, sugar, sugar...
# 232076  (chicken breasts, green onion, red bell pepper...
# 232083  (eggs, milk, fresh sage, fresh thyme, garlic c...
# 79222   (butter, onion, garlic, potatoes, flour, milk,...
# 393638  (lean ground beef, ketchup, heinz chili sauce,...
#
#                                       ingredients_raw_str serving_size  \
# id
# 96313   (4   cups    water, 1   cup   uncooked old fas...    1 (155 g)
# 232037  (1   medium    onion, chopped coarse , 1   med...    1 (366 g)
# 41090   (1   cup   canned white beans, rinsed and drai...    1 (807 g)
# 60656   (2       zucchini, sliced , 2   small    yello...    1 (244 g)
# 232047  (3   lbs    beef stew meat, 3   tablespoons   ...    1 (358 g)
# 232050  (12   ounces    slivered almonds, 1/4  cup    ...    1 (832 g)
# 232076  (4   cups   roasted chopped chicken breasts, 1...     1 (85 g)
# 232083  (8       eggs, 1/2  cup    milk, 1   tablespoo...    1 (499 g)
# 79222   (2   tablespoons    butter, 1   medium    onio...    1 (362 g)
# 393638  (1   lb    lean ground beef, 1/2  cup    ketch...    1 (103 g)
#
#         servings                                              steps  \
# id
# 96313          8  (I a sauce pan, bring water to a boil; slowly ...
# 232037         4  (In a food processor, pulse the onion, red pep...
# 41090          1  (In a large bowl, combine beans, tomato, onion...
# 60656          4  (Put all ingredients in the crock pot and cook...
# 232047         8  (Preheat oven to 350°F., Cut beef into 1 inch ...
# 232050         1  (Preheat oven to 375°F  Place almonds in singl...
# 232076         6  (In large bowl, combine chicken, green onion, ...
# 232083         4  (Beat the eggs in a bowl. Add the milk, sage, ...
# 79222          6  (Saute onion& garlic in melted butter in large...
# 393638         4  (Brown ground beef  with onion powder in a fry...
#
#                                                      tags  \
# id
# 96313   (pasta-rice-and-grains, stove-top, presentatio...
# 232037  (course, shrimp, preparation, main-ingredient,...
# 41090   (dinner-party, 3-steps-or-less, american, bean...
# 60656   (3-steps-or-less, vegetables, equipment, prepa...
# 232047  (course, preparation, main-ingredient, main-di...
# 232050  (low-cholesterol, course, preparation, time-to...
# 232076  (course, preparation, main-ingredient, cassero...
# 232083  (course, cuisine, gluten-free, preparation, ma...
# 79222   (stove-top, vegetables, low-fat, low-calorie, ...
# 393638  (low-carb, inexpensive, course, high-in-someth...
#
#                                              search_terms
# id
# 96313   (low-carb, diabetic, low-calorie, side, vegeta...
# 232037                                   (dinner, shrimp)
# 41090            (vegan, salad, side, dinner, vegetarian)
# 60656                         (italian, vegetarian, side)
# 232047                                          (dinner,)
# 232050                                         (dessert,)
# 232076                       (chicken, dinner, casserole)
# 232083                           (gluten-free, breakfast)
# 79222         (low-fat, healthy, low-calorie, low-sodium)
# 393638                                  (low-carb, lunch)
# **Dataframe shape:** 494,963 rows × 9 columns
# ---
# #### Top Row
#
# Look at this *structured* data. 🙂
# {   'description': 'We love grits, this is another good way to serve them. A '
#                    'great alternative to a baked potato when served with '
#                    'grilled steak or chicken. I belive this recipe could be '
#                    'made with instant grits.The 2 1/2 hours for refrigeration '
#                    'is not include in time. The recipe comes from Tast of '
#                    "Home's Light and Tasty.",
#     'ingredients': (   'water',
#                        'grits',
#                        'salt',
#                        'cheddar cheese',
#                        'garlic',
#                        'olive oil'),
#     'ingredients_raw_str': (   '4   cups    water',
#                                '1   cup   uncooked old fashion grits',
#                                '1   teaspoon    salt',
#                                '4   ounces   shredded cheddar cheese',
#                                '1 -2   clove    garlic, minced ',
#                                '1   tablespoon    olive oil'),
#     'name': 'Grilled Garlic Cheese Grits',
#     'search_terms': (   'low-carb',
#                         'diabetic',
#                         'low-calorie',
#                         'side',
#                         'vegetarian'),
#     'serving_size': '1 (155 g)',
#     'servings': 8,
#     'steps': (   'I a sauce pan, bring water to a boil; slowly add grits and '
#                  'salt, stirring constantly; Reduce heat:simmer, uncovered, '
#                  'for 40-45 minutes or untill thickened, stirrin occasionally.',
#                  'Add cheese and garlic; stir until cheese is melted, Spray '
#                  '9-inch baking dish with nonstick cooking spray; Cover and '
#                  'refrigerate for 2 to 2 1/2 hours or until frim.',
#                  'Before starting the grill, coat the grill rack with nonstick '
#                  'cooking spray; Cut the grits into 3-inch squares; Brush both '
#                  'sides with olive oil.',
#                  'Grill, covered, over medium heat for 4 to 6 minutes on each '
#                  'side or until lightly browned.'),
#     'tags': frozenset({   '4-hours-or-less',
#                           'brunch',
#                           'cheese',
#                           'comfort-food',
#                           'course',
#                           'diabetic',
#                           'dietary',
#                           'eggs-dairy',
#                           'equipment',
#                           'grains',
#                           'low-calorie',
#                           'low-carb',
#                           'low-cholesterol',
#                           'low-in-something',
#                           'main-ingredient',
#                           'occasion',
#                           'pasta-rice-and-grains',
#                           'preparation',
#                           'presentation',
#                           'refrigerator',
#                           'served-hot',
#                           'side-dishes',
#                           'stove-top',
#                           'taste-mood',
#                           'time-to-make',
#                           'vegetarian'})}
